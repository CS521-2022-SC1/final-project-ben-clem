# %% [markdown]
# # Setting up

# %% [markdown]
# ## Installing packages

# %% [markdown]
# <div align="center">
#     <img src="https://emojipedia-us.s3.dualstack.us-west-1.amazonaws.com/thumbs/320/apple/325/snake_1f40d.png">
# </div>

# %% [markdown]
# <h1 align="center">Centered text!</h1>

# %%
import sys
# !{sys.executable} -m pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (0.1.22)
# Requirement already satisfied: click in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from opendatasets) (8.1.3)
# Requirement already satisfied: tqdm in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from opendatasets) (4.64.0)
# Requirement already satisfied: kaggle in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: urllib3 in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from kaggle->opendatasets) (1.26.9)
# Requirement already satisfied: six>=1.10 in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: requests in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from kaggle->opendatasets) (2.27.1)
# Requirement already satisfied: certifi in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from kaggle->opendatasets) (2021.10.8)
# Requirement already satisfied: python-dateutil in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: python-slugify in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from kaggle->opendatasets) (6.1.2)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->kaggle->opendatasets) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/benzinho/Library/jupyterlab-desktop/jlab_server/lib/python3.8/site-packages (from requests->kaggle->opendatasets) (2.0.12)

# %% [markdown]
# # Importing dependencies

# %%
import opendatasets as od
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Downloading dataset

# %%
od.download('https://www.kaggle.com/datasets/moltean/fruits') # 1.28GB, took me ≈5min to DL
# Out:
# Skipping, found downloaded files in "./fruits" (use force=True to force download)

# %%
img = mpimg.imread('./fruits/fruits-360_dataset/fruits-360/Training/Apple Braeburn/0_100.jpg')
print(img.shape)
plt.imshow(img)
# Out:
# (100, 100, 3)
